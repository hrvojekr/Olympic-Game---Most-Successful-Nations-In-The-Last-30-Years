# %%
import os 
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "path-to-your-json"

from google.cloud import bigquery
bigquery_client = bigquery.Client()

import pandas as pd

# %%
q1 = """
SELECT * 
FROM `learningbigquery-325010.OI.Olympic_Game`
  """
qr1 = bigquery_client.query(q1)
oi_data = qr1.to_dataframe()

oi_data.head()
# Out:
#                        Nation Abbreviation  Gold  Silver  Bronze  Total  Year  \
# 0               United States          USA    39      41      33    113  2020
# 1  People's Republic of China          CHN    38      32      18     88  2020
# 2                       Japan          JPN    27      14      17     58  2020
# 3               Great Britain          GBR    22      21      22     65  2020
# 4   Russian Olympic Committee          ROC    20      28      23     71  2020
#
#      Type   Host
# 0  Summer  Japan
# 1  Summer  Japan
# 2  Summer  Japan
# 3  Summer  Japan
# 4  Summer  Japan

# %%
total_w = 3 * oi_data.Gold + 2 * oi_data.Silver + 1 * oi_data.Bronze
oi_data['Total_Weighted_Medals'] = total_w
oi_data
# Out:
#                                     Nation Abbreviation  Gold  Silver  Bronze  \
# 0                            United States          USA    39      41      33
# 1               People's Republic of China          CHN    38      32      18
# 2                                    Japan          JPN    27      14      17
# 3                            Great Britain          GBR    22      21      22
# 4                Russian Olympic Committee          ROC    20      28      23
# ..                                     ...          ...   ...     ...     ...
# 842                             Luxembourg          LUX     0       2       0
# 843                            New Zealand          NZL     0       1       0
# 844                         Czechoslovakia          TCH     0       0       3
# 845  Democratic People's Republic of Korea          PRK     0       0       1
# 846                                  Spain          ESP     0       0       1
#
#      Total  Year    Type    Host  Total_Weighted_Medals
# 0      113  2020  Summer   Japan                    232
# 1       88  2020  Summer   Japan                    196
# 2       58  2020  Summer   Japan                    126
# 3       65  2020  Summer   Japan                    130
# 4       71  2020  Summer   Japan                    139
# ..     ...   ...     ...     ...                    ...
# 842      2  1992  Winter  France                      4
# 843      1  1992  Winter  France                      2
# 844      3  1992  Winter  France                      3
# 845      1  1992  Winter  France                      1
# 846      1  1992  Winter  France                      1
#
# [847 rows x 10 columns]

# %%
oi_data = oi_data.groupby('Nation')['Total_Weighted_Medals'].sum().reset_index()
oi_data = oi_data.sort_values(by = 'Total_Weighted_Medals', ascending = False)

# %%
oi_data.head(10)
# Out:
#                          Nation  Total_Weighted_Medals
# 128               United States                   2146
# 88   People's Republic of China                   1354
# 42                      Germany                   1285
# 98           Russian Federation                   1100
# 44                Great Britain                    719
# 39                       France                    706
# 4                     Australia                    661
# 57                        Italy                    638
# 95            Republic of Korea                    597
# 18                       Canada                    590

# %%
q2 = """
SELECT Country__or_dependency_, Population__2020_ FROM `learningbigquery-325010.OI.Population_Countries_2020` 
ORDER BY Population__2020_ DESC
"""

qr2 = bigquery_client.query(q2)
pop = qr2.to_dataframe()

pop.head()
# Out:
#   Country__or_dependency_  Population__2020_
# 0                   China         1438207241
# 1                   India         1377233523
# 2           United States          330610570
# 3               Indonesia          272931713
# 4                Pakistan          219992900

# %%
pop = pop.rename(columns = {'Country__or_dependency_':'Nation',
                            'Population__2020_':'Population'})

pop.head()
# Out:
#           Nation  Population
# 0          China  1438207241
# 1          India  1377233523
# 2  United States   330610570
# 3      Indonesia   272931713
# 4       Pakistan   219992900

# %%
med_pop = pd.merge(oi_data,pop,on='Nation',how='inner')

med_pop
# Out:
#             Nation  Total_Weighted_Medals  Population
# 0    United States                   2146   330610570
# 1          Germany                   1285    83730223
# 2           France                    706    65244628
# 3        Australia                    661    25439164
# 4            Italy                    638    60479424
# ..             ...                    ...         ...
# 111       Pakistan                      1   219992900
# 112  Liechtenstein                      1       38106
# 113       Barbados                      1      287305
# 114      Mauritius                      1     1271347
# 115       Suriname                      1      585561
#
# [116 rows x 3 columns]

# %%
no_match = oi_data.loc[~oi_data['Nation'].isin(med_pop.Nation)]
no_match
# Out:
#                                     Nation  Total_Weighted_Medals
# 88              People's Republic of China                   1354
# 98                      Russian Federation                   1100
# 44                           Great Britain                    719
# 95                       Republic of Korea                    597
# 126                           Unified Team                    287
# 26                          Czech Republic                    186
# 99               Russian Olympic Committee                    166
# 55                Islamic Republic of Iran                     98
# 29   Democratic People's Republic of Korea                     82
# 20                          Chinese Taipei                     57
# 117                            The Bahamas                     30
# 27                          Czechoslovakia                     20
# 103                  Serbia and Montenegro                     17
# 48                        Hong Kong, China                     16
# 64                                  Kosovo                      9
# 96                     Republic of Moldova                      8
# 52             Individual Olympic Athletes                      8
# 63                 Kingdom of Saudi Arabia                      6
# 114                   Syrian Arab Republic                      5

# %%
oi_data['Nation'].replace(
    
    ["People's Republic of China",
    "Russian Federation",
    "Great Britain",
    "Republic of Korea",
    "Czech Republic",
    "Russian Olympic Committee",
    "Islamic Republic of Iran",
    "Democratic People's Republic of Korea",
    "Chinese Taipei",
    "The Bahamas",
    "Hong Kong, China",
    "Serbia and Montenegro",
    "Republic of Moldova",
    "Kingdom of Saudi Arabia",
    "Syrian Arab Republic"],

    ["China",
     "Russia",
     "United Kingdom",
     "South Korea",
     "Czech Republic (Czechia)",
     "Russia",
     "Iran",
     "North Korea",
     "Taiwan",
     "Bahamas",
     "Hong Kong",
     "Serbia",
     "Moldova",
     "Saudi Arabia",
     "Syria"], inplace = True
)

oi_data
# Out:
#              Nation  Total_Weighted_Medals
# 128   United States                   2146
# 88            China                   1354
# 42          Germany                   1285
# 98           Russia                   1100
# 44   United Kingdom                    719
# ..              ...                    ...
# 85         Pakistan                      1
# 68    Liechtenstein                      1
# 8          Barbados                      1
# 72        Mauritius                      1
# 111        Suriname                      1
#
# [135 rows x 2 columns]

# %%
med_pop_con = pd.merge(oi_data,pop,on='Nation',how='inner')

med_pop_con
# Out:
#             Nation  Total_Weighted_Medals  Population
# 0    United States                   2146   330610570
# 1            China                   1354  1438207241
# 2          Germany                   1285    83730223
# 3           Russia                   1100   145922010
# 4           Russia                    166   145922010
# ..             ...                    ...         ...
# 126       Pakistan                      1   219992900
# 127  Liechtenstein                      1       38106
# 128       Barbados                      1      287305
# 129      Mauritius                      1     1271347
# 130       Suriname                      1      585561
#
# [131 rows x 3 columns]

# %%
med_w_pop = (med_pop_con.Total_Weighted_Medals / med_pop_con.Population)*100000
med_pop_con['Number Of Medals per 100k Inhabitants'] = med_w_pop
med_pop_con
# Out:
#             Nation  Total_Weighted_Medals  Population  \
# 0    United States                   2146   330610570
# 1            China                   1354  1438207241
# 2          Germany                   1285    83730223
# 3           Russia                   1100   145922010
# 4           Russia                    166   145922010
# ..             ...                    ...         ...
# 126       Pakistan                      1   219992900
# 127  Liechtenstein                      1       38106
# 128       Barbados                      1      287305
# 129      Mauritius                      1     1271347
# 130       Suriname                      1      585561
#
#      Number Of Medals per 100k Inhabitants
# 0                                 0.649102
# 1                                 0.094145
# 2                                 1.534691
# 3                                 0.753827
# 4                                 0.113759
# ..                                     ...
# 126                               0.000455
# 127                               2.624259
# 128                               0.348062
# 129                               0.078657
# 130                               0.170776
#
# [131 rows x 4 columns]

# %%
med_pop_most_s = med_pop_con.sort_values(by = 'Number Of Medals per 100k Inhabitants', ascending = False)
med_pop_most_s.head(50)
# Out:
#                        Nation  Total_Weighted_Medals  Population  \
# 99                 San Marino                      4       33917
# 12                     Norway                    542     5412632
# 60                    Bahamas                     30      392477
# 90                    Grenada                      6      112418
# 102                   Bermuda                      3       62323
# 30                    Jamaica                    137     2958567
# 40                   Slovenia                     79     2078881
# 26                New Zealand                    172     4814272
# 16                    Austria                    295     8996022
# 15                    Hungary                    316     9665192
# 54                    Estonia                     43     1326357
# 14                       Cuba                    359    11327988
# 19                Switzerland                    269     8641786
# 13                Netherlands                    516    17127290
# 18                     Sweden                    285    10086531
# 127             Liechtenstein                      1       38106
# 34                    Croatia                    107     4110214
# 7                   Australia                    661    25439164
# 52                     Latvia                     49     1890218
# 28                    Finland                    143     5539002
# 32                    Denmark                    128     5788108
# 29                   Bulgaria                    142     6958627
# 25                    Belarus                    180     9449940
# 109                     Tonga                      2      105449
# 43                    Georgia                     72     3990681
# 24   Czech Republic (Czechia)                    186    10705012
# 53                  Lithuania                     45     2729553
# 10                     Canada                    590    37674770
# 38                   Slovakia                     84     5459116
# 2                     Germany                   1285    83730223
# 72        Trinidad and Tobago                     19     1398579
# 9                 South Korea                    597    51260395
# 33                     Greece                    116    10433037
# 22                    Romania                    210    19262731
# 6                      France                    706    65244628
# 5              United Kingdom                    719    67814098
# 8                       Italy                    638    60479424
# 62                    Armenia                     30     2962137
# 118                     Samoa                      2      198147
# 64                   Mongolia                     29     3267320
# 104                   Iceland                      3      340795
# 57                    Ireland                     42     4926480
# 87                       Fiji                      7      895128
# 42                 Azerbaijan                     77    10120555
# 3                      Russia                   1100   145922010
# 31                 Kazakhstan                    136    18730568
# 0               United States                   2146   330610570
# 97                 Luxembourg                      4      623861
# 21                     Poland                    240    37854825
# 17                      Spain                    292    46751175
#
#      Number Of Medals per 100k Inhabitants
# 99                               11.793496
# 12                               10.013613
# 60                                7.643760
# 90                                5.337224
# 102                               4.813632
# 30                                4.630620
# 40                                3.800121
# 26                                3.572710
# 16                                3.279227
# 15                                3.269464
# 54                                3.241963
# 14                                3.169142
# 19                                3.112782
# 13                                3.012736
# 18                                2.825550
# 127                               2.624259
# 34                                2.603271
# 7                                 2.598356
# 52                                2.592294
# 28                                2.581693
# 32                                2.211431
# 29                                2.040632
# 25                                1.904774
# 109                               1.896651
# 43                                1.804203
# 24                                1.737504
# 53                                1.648622
# 10                                1.566035
# 38                                1.538711
# 2                                 1.534691
# 72                                1.358522
# 9                                 1.164642
# 33                                1.111853
# 22                                1.090188
# 6                                 1.082081
# 5                                 1.060252
# 8                                 1.054904
# 62                                1.012782
# 118                               1.009352
# 64                                0.887578
# 104                               0.880295
# 57                                0.852536
# 87                                0.782011
# 42                                0.760828
# 3                                 0.753827
# 31                                0.726086
# 0                                 0.649102
# 97                                0.641168
# 21                                0.634001
# 17                                0.624583

# %%
import atoti as tt

session = tt.create_session()
# Out:
# Welcome to atoti 0.6.4!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %%
med_pop_graph = session.read_pandas(med_pop_most_s, keys=["Nation"], table_name="Nation Medals")

# %%
med_pop_graph.head()
# Out:
#             Total_Weighted_Medals  Population  \
# Nation
# San Marino                      4       33917
# Norway                        542     5412632
# Bahamas                        30      392477
# Grenada                         6      112418
# Bermuda                         3       62323
#
#             Number Of Medals per 100k Inhabitants
# Nation
# San Marino                              11.793496
# Norway                                  10.013613
# Bahamas                                  7.643760
# Grenada                                  5.337224
# Bermuda                                  4.813632

# %%
cube = session.create_cube(med_pop_graph)

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.
